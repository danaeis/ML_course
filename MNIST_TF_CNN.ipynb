# %% [markdown]
# <a href="https://colab.research.google.com/github/danaeis/ML_course/blob/main/MNIST_TF_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import Model, layers
import numpy as np

import tensorflow.keras as keras

# %% [markdown]
# ## initialization

# %%
num_class = 10

# trainning parameters
learning_rate = 0.001
training_steps = 200
batch_size = 128
display_step = 10


# network parameters
conv1_filters = 32 # number of filters for the first conv layer
conv1_filters = 64
fcl_units = 1024 # number of neurins for the fully connected layer

# %% [markdown]
# ## prepare dataset

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test,y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
x_train, x_test = x_train/255.0, x_test/255.0

# %%
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.repeat().shuffle(5000).batch(batch_size).prefetch(1)

# %% [markdown]
# ##create TF model
# ![Screenshot from 2023-07-08 18-15-35.png](data:image/png;base64,...)

# %%
# !git commit -b "prepare data for cnn model"
# Out:
# error: pathspec 'prepare data for cnn model' did not match any file(s) known to git

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git commit -m "initializing cnn model on mnist dataset"
# Out:
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git config --global user.email "saeidedanaei@google.com"

# %%
# !git remote add origin https://github.com/danaeis/ML_course.git

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/danaeis/ML_course.git'
